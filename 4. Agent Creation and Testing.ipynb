# %% [markdown]
# #Tool-calling Agent
#
# This is an auto-generated notebook created by an AI playground export. In this notebook, you will:
# - Author a tool-calling [MLflow's `ResponsesAgent`](https://mlflow.org/docs/latest/api_reference/python_api/mlflow.pyfunc.html#mlflow.pyfunc.ResponsesAgent) that uses the OpenAI client
# - Manually test the agent's output
# - Evaluate the agent with Mosaic AI Agent Evaluation
# - Log and deploy the agent
#
# This notebook should be run on serverless or a cluster with DBR<17.
#
#  **_NOTE:_**  This notebook uses the OpenAI SDK, but AI Agent Framework is compatible with any agent authoring framework, including LlamaIndex or LangGraph. To learn more, see the [Authoring Agents](https://docs.databricks.com/generative-ai/agent-framework/author-agent) Databricks documentation.

# %%
# %pip install -U -qqqq backoff databricks-openai uv databricks-agents mlflow-skinny[databricks]
dbutils.library.restartPython()
# Out:
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import mlflow
display(mlflow.__version__)
# Out:
# '3.8.1'

# %% [markdown]
# ## Define the agent in code
# Below we define our agent code in a single cell, enabling us to easily write it to a local Python file for subsequent logging and deployment using the `%%writefile` magic command.
#
# For more examples of tools to add to your agent, see [docs](https://docs.databricks.com/generative-ai/agent-framework/agent-tool.html).

# %%
# %%writefile agent.py
import json
from typing import Any, Callable, Generator, Optional
from uuid import uuid4
import warnings

import backoff
import mlflow
import openai
from databricks.sdk import WorkspaceClient
from databricks_openai import UCFunctionToolkit, VectorSearchRetrieverTool
from mlflow.entities import SpanType
from mlflow.pyfunc import ResponsesAgent
from mlflow.types.responses import (
    ResponsesAgentRequest,
    ResponsesAgentResponse,
    ResponsesAgentStreamEvent,
)
from openai import OpenAI
from pydantic import BaseModel
from unitycatalog.ai.core.base import get_uc_function_client

############################################
# Define your LLM endpoint and system prompt
############################################
# LLM_ENDPOINT_NAME = "databricks-claude-sonnet-4-5"
LLM_ENDPOINT_NAME = "databricks-gpt-5"
INDEX_NAME = "fnma_product_catalog_jcg.default.product_catalog_vector_index" 

SYSTEM_PROMPT = """Role

You are an intelligent assistant designed to help business and data users discover the most relevant data products from a vector search index that contains embeddings of data product metadata, schemas, and descriptions.

Your job is to:
	•	Interpret the user's query.
	•	Search the vector database for relevant data products.
	•	Rank and summarize up to three of the most relevant ones.
	•	Present the results in a structured, business-friendly JSON format.

⸻

Core Objectives
	1.	Understand Intent:
Determine what kind of data the user is seeking (e.g., borrower info, credit risk, transactions).
	2.	Perform Vector Search:
Use the query to find semantically relevant data products.
3.	Rank Results by Relevance & Quality:
Rank retrieved products using:
	•	Semantic Relevance (40%) — closeness to the query
	•	Data Completeness (25%) — coverage of relevant attributes
	•	Freshness (20%) — based on last update or processing date
	•	Business Value (10%) — usefulness for decision-making
	•	Ownership Transparency (5%) — presence of a known owner/contact
4.	Summarize Each Data Product:
Provide a concise but meaningful business summary, including:
	•	Description
	•	Key fields
	•	Owner
	•	Freshness
	•	Link to the Unity Catalog for access
5.	Output in a clean, structured JSON template suitable for both human and system consumption. Only Output the json response.

⸻

Output Format Template

The response must always follow this structured format:

{
  "query_understanding": "<Short summary of what the user is asking for>",
  "search_query": "<The query text used in vector search>",
  "results": [
    {
      "rank": 1,
      "data_product_name": "<name of the data product>",
      "full_identifier": "<Populate as is from Product_Name column which is a metadata column in the vector search index table. Do not change the value>",
      "table_names": "<Populate as is from table_names column which is a metadata column in the vector search index table. Do not change the value>",
      "description": "<business-friendly explanation of what this data product contains and how it's used. Be concise and limit in max 3 sentences>",
      "completeness_score": "<High | Medium | Low>"
    },
    {
      "rank": 2,
      ...
    },
    {
      "rank": 3,
      ...
    }
  ],
  "recommended_action": "<Business-friendly suggestion for how to use the top data product(s) together or in context>"
}

Style and Tone
	•	For the metadata generation, use the exact data available in the vector search, do not make stuff up.
        •	Write in clear, executive-level English suitable for data analysts, product managers, or business stakeholders.
	•	Keep technical details concise and readable.
	•	Use simple explanations for field names and table purposes.
	•	Limit output to no more than three results to avoid cognitive overload.
"""


###############################################################################
## Define tools for your agent, enabling it to retrieve data or take actions
## beyond text generation
## To create and see usage examples of more tools, see
## https://docs.databricks.com/generative-ai/agent-framework/agent-tool.html
###############################################################################
class ToolInfo(BaseModel):
    """
    Class representing a tool for the agent.
    - "name" (str): The name of the tool.
    - "spec" (dict): JSON description of the tool (matches OpenAI Responses format)
    - "exec_fn" (Callable): Function that implements the tool logic
    """

    name: str
    spec: dict
    exec_fn: Callable


def create_tool_info(tool_spec, exec_fn_param: Optional[Callable] = None):
    tool_spec["function"].pop("strict", None)
    tool_name = tool_spec["function"]["name"]
    udf_name = tool_name.replace("__", ".")

    # Define a wrapper that accepts kwargs for the UC tool call,
    # then passes them to the UC tool execution client
    def exec_fn(**kwargs):
        function_result = uc_function_client.execute_function(udf_name, kwargs)
        if function_result.error is not None:
            return function_result.error
        else:
            return function_result.value
    return ToolInfo(name=tool_name, spec=tool_spec, exec_fn=exec_fn_param or exec_fn)


TOOL_INFOS = []

# You can use UDFs in Unity Catalog as agent tools
UC_TOOL_NAMES = []

uc_toolkit = UCFunctionToolkit(function_names=UC_TOOL_NAMES)
uc_function_client = get_uc_function_client()
for tool_spec in uc_toolkit.tools:
    TOOL_INFOS.append(create_tool_info(tool_spec))


# Use Databricks vector search indexes as tools
# See [docs](https://docs.databricks.com/generative-ai/agent-framework/unstructured-retrieval-tools.html) for details

# Use Databricks vector search indexes as tools
# See the [Databricks Documentation](https://docs.databricks.com/generative-ai/agent-framework/unstructured-retrieval-tools.html) for details
VECTOR_SEARCH_TOOLS = []
VECTOR_SEARCH_TOOLS.append(
        VectorSearchRetrieverTool(
            index_name=INDEX_NAME,
            columns=["Product_Name", "Description", "table_names","TAG_NAME","TAG_VALUE"],
            # TODO: specify index description for better agent tool selection
            tool_description="Use this vector search index tool to search and identify relevant schema descriptions, data definitions, and domain context across mortgage, housing, property, servicing, fraud, investor, and credit-risk datasets. It helps the agent quickly retrieve structured knowledge for data discovery, analytics reasoning, and answering domain-specific questions"
        )
    )

for vs_tool in VECTOR_SEARCH_TOOLS:
    TOOL_INFOS.append(create_tool_info(vs_tool.tool, vs_tool.execute))



class ToolCallingAgent(ResponsesAgent):
    """
    Class representing a tool-calling Agent
    """

    def __init__(self, llm_endpoint: str, tools: list[ToolInfo]):
        """Initializes the ToolCallingAgent with tools."""
        self.llm_endpoint = llm_endpoint
        self.workspace_client = WorkspaceClient()
        self.model_serving_client: OpenAI = (
            self.workspace_client.serving_endpoints.get_open_ai_client()
        )
        self._tools_dict = {tool.name: tool for tool in tools}

    def get_tool_specs(self) -> list[dict]:
        """Returns tool specifications in the format OpenAI expects."""
        return [tool_info.spec for tool_info in self._tools_dict.values()]

    @mlflow.trace(span_type=SpanType.TOOL)
    def execute_tool(self, tool_name: str, args: dict) -> Any:
        """Executes the specified tool with the given arguments."""
        return self._tools_dict[tool_name].exec_fn(**args)

    def call_llm(self, messages: list[dict[str, Any]]) -> Generator[dict[str, Any], None, None]:
        with warnings.catch_warnings():
            warnings.filterwarnings("ignore", message="PydanticSerializationUnexpectedValue")
            for chunk in self.model_serving_client.chat.completions.create(
                model=self.llm_endpoint,
                messages=self.prep_msgs_for_cc_llm(messages),
                tools=self.get_tool_specs(),
                stream=True,
            ):
                chunk_dict = chunk.to_dict()
                if len(chunk_dict.get("choices", [])) > 0:
                    yield chunk_dict

    def handle_tool_call(
        self,
        tool_call: dict[str, Any],
        messages: list[dict[str, Any]],
    ) -> ResponsesAgentStreamEvent:
        """
        Execute tool calls, add them to the running message history, and return a ResponsesStreamEvent w/ tool output
        """
        args = json.loads(tool_call["arguments"])
        result = str(self.execute_tool(tool_name=tool_call["name"], args=args))

        tool_call_output = self.create_function_call_output_item(tool_call["call_id"], result)
        messages.append(tool_call_output)
        return ResponsesAgentStreamEvent(type="response.output_item.done", item=tool_call_output)

    def call_and_run_tools(
        self,
        messages: list[dict[str, Any]],
        max_iter: int = 10,
    ) -> Generator[ResponsesAgentStreamEvent, None, None]:
        for _ in range(max_iter):
            last_msg = messages[-1]
            if last_msg.get("role", None) == "assistant":
                return
            elif last_msg.get("type", None) == "function_call":
                yield self.handle_tool_call(last_msg, messages)
            else:
                yield from self.output_to_responses_items_stream(
                    chunks=self.call_llm(messages), aggregator=messages
                )

        yield ResponsesAgentStreamEvent(
            type="response.output_item.done",
            item=self.create_text_output_item("Max iterations reached. Stopping.", str(uuid4())),
        )

    def predict(self, request: ResponsesAgentRequest) -> ResponsesAgentResponse:
        outputs = [
            event.item
            for event in self.predict_stream(request)
            if event.type == "response.output_item.done"
        ]
        return ResponsesAgentResponse(output=outputs, custom_outputs=request.custom_inputs)

    def predict_stream(
        self, request: ResponsesAgentRequest
    ) -> Generator[ResponsesAgentStreamEvent, None, None]:
        messages = self.prep_msgs_for_cc_llm([i.model_dump() for i in request.input])
        if SYSTEM_PROMPT:
            messages.insert(0, {"role": "system", "content": SYSTEM_PROMPT})
        yield from self.call_and_run_tools(messages=messages)


# Log the model using MLflow
mlflow.openai.autolog()
AGENT = ToolCallingAgent(llm_endpoint=LLM_ENDPOINT_NAME, tools=TOOL_INFOS)
mlflow.models.set_model(AGENT)
# Out:
# Overwriting agent.py

# %% [markdown]
# ## Test the agent
#
# Interact with the agent to test its output. Since we manually traced methods within `ResponsesAgent`, you can view the trace for each step the agent takes, with any LLM calls made via the OpenAI SDK automatically traced by autologging.
#
# Replace this placeholder input with an appropriate domain-specific example for your agent.

# %%
import os, sys

# # If needed, replace with the directory that actually contains agent.py
# agent_dir = "/Workspace/Users/joy.garnett@databricks.com/Customer Questions/FNMA/App Setup Github Ready/"  

# if agent_dir not in sys.path:
#     sys.path.append(agent_dir)

from agent import AGENT

AGENT.predict({"input": [{"role": "user", "content": "borrowers"}]})
# Out:
# [NOTICE] Using a notebook authentication token. Recommended for development only. For improved performance, please use Service Principal based authentication. To disable this message, pass disable_notice=True.
# ResponsesAgentResponse(tool_choice=None, truncation=None, id=None, created_at=None, error=None, incomplete_details=None, instructions=None, metadata=None, model=None, object='response', output=[OutputItem(type='function_call', id='chatcmpl-CyJwFOF3xaucWrIAUbfKyfRyPIh8n', call_id='call_ELEViEE7lzHoagbr5mS9eFvu', name='fnma_product_catalog_jcg__default__product_catalog_vector_index', arguments='{"query":"borrowers data product borrower information demographics credit profile mortgage borrower dataset"}'), OutputItem(type='function_call_output', call_id='call_ELEViEE7lzHoagbr5mS9eFvu', output='[{\'page_content\': \'## Product Overview\\n\\nThis data product organizes data related to the acquisition and origination of loans. It includes tables for **borrower demographics**, **loan applications**, and **loan acquisition records**. Use this product for:\\n\\n- Analyzing loan origination processes\\n- Understanding borrower profiles\\n- Tracking acquisition metrics\\n\\n## Purpose\\n\\n- **Track trends** in loan acquisition\\n- Analyze **borrower profiles**\\n- Assess **application processes**\\n\\n## Tables\\n\\n1. **Loan Acquisition**\\n\\n- Tracks details of loan acquisitions.\\n- Fields: Acquisition Date, Loan Amount, Seller, etc.\\n\\n2. **Loan Application**\\n\\n- Contains applicant information and application status.\\n- Fields: Application ID, Borrower ID, Application Status, Loan Type, etc.\\n\\n3. **Borrower Demographics**\\n\\n- Stores demographic details of borrowers.\\n- Fields: Borrower ID, Age, Income, Employment Status, etc.\\n\\n4. **Credit History**\\n\\n- Records the credit history of borrowers.\\n- Fields: Borrower ID, Credit Score, Historical Defaults, etc.\\n\\n## Ideal Customers\\n\\n- **Fannie Mae acquisition teams** for portfolio analysis.\\n- **Lenders** to evaluate risk and approve loans.\\n- **Risk modelers** to improve credit risk models.\\n- **Business analysts** to drive data-driven decisions.\\n\\n## Uses\\n\\n- **Identify emerging origination patterns**\\n- **Gauge credit risk** at the entry point\\n- Understand **borrower diversity and affordability**\\n\\nBy utilizing this schema, stakeholders can effectively analyze and interpret critical aspects of the loan origination and acquisition processes.\', \'metadata\': {\'Product_Name\': \'acquisition_and_origination_analytics\', \'table_names\': \'[{"table_name":"loan_acquisition","description":"The table contains data related to loan origination, including details about the borrower and the loan itself. It can be used to analyze lending patterns, assess borrower demographics, and evaluate loan performance. Key information includes loan amounts, borrower income, loan-to-value ratios, and whether the borrower is a first-time homebuyer."},{"table_name":"application_table","description":"The table contains data related to loan applications. It includes details such as the application ID, submission date, borrower information, property details, employment history, total debt, monthly income, and the purpose of the loan. This data can be used for analyzing loan application trends, assessing borrower profiles, and evaluating the financial health of applicants."},{"table_name":"credit_history","description":"The table contains data related to borrowers\\\' credit profiles. It includes information such as the number of credit accounts, the age of those accounts, payment history, credit inquiries, and the debt-to-income ratio. This data can be used for analyzing borrower creditworthiness, assessing risk for lending decisions, and understanding trends in credit behavior."},{"table_name":"borrower_demographics","description":"The table contains demographic and financial information about borrowers. It includes details such as race, ethnicity, gender, date of birth, income, and the number of borrowers associated with each record. This data can be used for analyzing borrower profiles, understanding lending patterns, and assessing the impact of demographic factors on ...
# Trace(trace_id=tr-2e36ecb9cd887a1ca27cc08b14a6a9b8)

# %%
for chunk in AGENT.predict_stream(
    {"input": [{"role": "user", "content": "borower data"}]}
):
    print(chunk.model_dump(exclude_none=True))
# Out:
# {'type': 'response.output_item.done', 'item': {'type': 'function_call', 'id': 'chatcmpl-CyJwXGaLIFFvygxdwFq03M8QAw8mu', 'call_id': 'call_DxgefgRbTzuCeDfmIoCBAemI', 'name': 'fnma_product_catalog_jcg__default__product_catalog_vector_index', 'arguments': '{"query":"borrower data: borrower demographics, income, credit, applications, mortgage, loan origination, underwriting, credit risk, applicant, co-borrower"}'}}
# [NOTICE] Using a notebook authentication token. Recommended for development only. For improved performance, please use Service Principal based authentication. To disable this message, pass disable_notice=True.
# {'type': 'response.output_item.done', 'item': {'type': 'function_call_output', 'call_id': 'call_DxgefgRbTzuCeDfmIoCBAemI', 'output': '[{\'page_content\': \'## Product Overview\\n\\nThis data product organizes data related to the acquisition and origination of loans. It includes tables for **borrower demographics**, **loan applications**, and **loan acquisition records**. Use this product for:\\n\\n- Analyzing loan origination processes\\n- Understanding borrower profiles\\n- Tracking acquisition metrics\\n\\n## Purpose\\n\\n- **Track trends** in loan acquisition\\n- Analyze **borrower profiles**\\n- Assess **application processes**\\n\\n## Tables\\n\\n1. **Loan Acquisition**\\n\\n- Tracks details of loan acquisitions.\\n- Fields: Acquisition Date, Loan Amount, Seller, etc.\\n\\n2. **Loan Application**\\n\\n- Contains applicant information and application status.\\n- Fields: Application ID, Borrower ID, Application Status, Loan Type, etc.\\n\\n3. **Borrower Demographics**\\n\\n- Stores demographic details of borrowers.\\n- Fields: Borrower ID, Age, Income, Employment Status, etc.\\n\\n4. **Credit History**\\n\\n- Records the credit history of borrowers.\\n- Fields: Borrower ID, Credit Score, Historical Defaults, etc.\\n\\n## Ideal Customers\\n\\n- **Fannie Mae acquisition teams** for portfolio analysis.\\n- **Lenders** to evaluate risk and approve loans.\\n- **Risk modelers** to improve credit risk models.\\n- **Business analysts** to drive data-driven decisions.\\n\\n## Uses\\n\\n- **Identify emerging origination patterns**\\n- **Gauge credit risk** at the entry point\\n- Understand **borrower diversity and affordability**\\n\\nBy utilizing this schema, stakeholders can effectively analyze and interpret critical aspects of the loan origination and acquisition processes.\', \'metadata\': {\'Product_Name\': \'acquisition_and_origination_analytics\', \'table_names\': \'[{"table_name":"loan_acquisition","description":"The table contains data related to loan origination, including details about the borrower and the loan itself. It can be used to analyze lending patterns, assess borrower demographics, and evaluate loan performance. Key information includes loan amounts, borrower income, loan-to-value ratios, and whether the borrower is a first-time homebuyer."},{"table_name":"application_table","description":"The table contains data related to loan applications. It includes details such as the application ID, submission date, borrower information, property details, employment history, total debt, monthly income, and the purpose of the loan. This data can be used for analyzing loan application trends, assessing borrower profiles, and evaluating the financial health of applicants."},{"table_name":"credit_history","description":"The table contains data related to borrowers\\\' credit profiles. It includes information such as the number of credit accounts, the age of those accounts, payment history, credit inquiries, and the debt-to-income ratio. This data can be used for analyzing borrower creditworthiness, assessing risk for lending decisions, and understanding trends in credit behavior."},{"table_name":"borrower_demographics","description":"The table contains demographic and financial information about borrowers. It includes details such as race, ethnicity, gender, date of birth, income, and the number of borrowers associated with each record. This data can be used for analyzing borrower profiles, understanding lending patterns, and assessing the impact of demographic factors on borrowing behavior."}]\', \'TAG_NAME\': \'RemoveAfter\', \'TAG_VALUE\': \'2027-01-31\', \'unique_id\': 1.0}}, {\'page_content\': \'## Collateral and Property Intelligence Schema\\n\\nThe schema organizes data related to collateral and property intelligence. It encompasses a variety of tables and functions designed to streamline property evaluations, risk assessments, and collateral management.\\n\\n### Purpose\\nCentralize and analyze property details and val ...
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ''}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '{\n'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' '}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' "'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'query'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_under'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'standing'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '":'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' "'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'User'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' is'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' looking'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' for'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' borrower'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' data'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' such'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' as'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' demographics'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' income'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' credit'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' application'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '/or'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'ig'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'ination'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' details'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '.",\n'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' '}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' "'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'search'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_query'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '":'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' "'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'borrow'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'er'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' data'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ':'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' borrower'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' demographics'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' income'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' credit'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' applications'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' mortgage'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' loan'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' orig'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'ination'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' underwriting'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' credit'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' risk'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' applicant'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' co'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '-b'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'orrow'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'er'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '",\n'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' '}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' "'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'results'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '":'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' [\n'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '   '}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' {\n'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '     '}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' "'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'rank'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '":'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' '}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '1'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ',\n'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '     '}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' "'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'data'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_product'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_name'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '":'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' "'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'ac'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'quisition'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_orig'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'ination'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'analytics'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '",\n'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '     '}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' "'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'full'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_identifier'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '":'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' "'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'ac'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'quisition'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_orig'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'ination'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'analytics'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '",\n'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '     '}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' "'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'table'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_names'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '":'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' "['}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '{\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'table'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_name'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '\\":\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'loan'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_ac'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'quisition'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '\\",\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'description'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '\\":\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'The'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' table'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' contains'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' data'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' related'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' to'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' loan'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' orig'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'ination'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' including'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' details'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' about'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' the'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' borrower'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' the'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' loan'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' itself'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '.'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' It'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' can'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' be'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' used'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' to'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' analyze'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' lending'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' patterns'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' assess'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' borrower'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' demographics'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' evaluate'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' loan'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' performance'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '.'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' Key'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' information'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' includes'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' loan'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' amounts'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' borrower'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' income'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' loan'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '-to'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '-value'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' ratios'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' whether'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' the'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' borrower'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' is'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' a'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' first'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '-time'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' home'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'buyer'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '.\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '},{'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'table'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_name'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '\\":\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'application'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_table'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '\\",\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'description'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '\\":\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'The'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' table'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' contains'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' data'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' related'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' to'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' loan'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' applications'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '.'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' It'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' includes'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' details'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' such'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' as'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' the'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' application'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' ID'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' submission'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' date'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' borrower'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' information'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' property'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' details'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' employment'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' history'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' total'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' debt'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' monthly'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' income'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' the'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' purpose'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' of'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' the'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' loan'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '.'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' This'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' data'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' can'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' be'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' used'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' for'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' analyzing'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' loan'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' application'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' trends'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' assessing'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' borrower'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' profiles'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' evaluating'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' the'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' financial'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' health'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' of'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' applicants'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '.\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '},{'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'table'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_name'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '\\":\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'credit'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_history'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '\\",\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'description'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '\\":\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'The'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' table'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' contains'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' data'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' related'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' to'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' borrowers'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': "'"}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' credit'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' profiles'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '.'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' It'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' includes'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' information'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' such'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' as'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' the'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' number'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' of'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' credit'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' accounts'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' the'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' age'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' of'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' those'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' accounts'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' payment'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' history'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' credit'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' inquiries'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' the'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' debt'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '-to'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '-income'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' ratio'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '.'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' This'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' data'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' can'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' be'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' used'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' for'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' analyzing'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' borrower'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' credit'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'worthiness'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' assessing'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' risk'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' for'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' lending'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' decisions'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' understanding'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' trends'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' in'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' credit'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' behavior'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '.\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '},{'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'table'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_name'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '\\":\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'borrow'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'er'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_dem'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'ographics'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '\\",\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'description'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '\\":\\"'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'The'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' table'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' contains'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' demographic'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' financial'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' information'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' about'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' borrowers'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '.'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' It'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' includes'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' details'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' such'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' as'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' race'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' ethnicity'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' gender'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' date'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' of'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' birth'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' income'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' the'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' number'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' of'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' borrowers'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' associated'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' with'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' each'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' record'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '.'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' This'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' data'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' can'}
# ...
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' "'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'Serv'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'icing'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' performance'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' view'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' to'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' track'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' borrower'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' payment'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' behavior'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' del'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'inqu'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'encies'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' over'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' time'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '.'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' Best'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' for'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' linking'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' borrower'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' loans'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' to'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' repayment'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' history'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' servicing'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' actions'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '.",\n'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '     '}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' "'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'com'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'ple'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'teness'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_score'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '":'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' "'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'Medium'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '"\n'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '   '}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' }\n'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' '}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' ],\n'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' '}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' "'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'recommended'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_action'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '":'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' "'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'Start'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' with'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' acquisition'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_orig'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'ination'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'analytics'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' for'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' borrower'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' demographics'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' income'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' applications'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' credit'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' history'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '.'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' Join'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' its'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' borrower'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '/application'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' keys'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' to'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' the'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' loan'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_per'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'formance'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_serv'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'icing'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' product'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' to'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' study'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' payment'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' outcomes'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ','}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' use'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' loss'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_credit'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_r'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'isk'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '_management'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' for'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' PD'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '/L'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': 'GD'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' modeling'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' and'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' loss'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': ' back'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '-testing'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '."\n'}
# {'type': 'response.output_text.delta', 'item_id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'delta': '}'}
# {'type': 'response.output_item.done', 'item': {'id': 'chatcmpl-CyJwZWjyHupBCLH3hPzuoyO3TFcF7', 'content': [{'text': '{\n  "query_understanding": "User is looking for borrower data, such as demographics, income, credit, and application/origination details.",\n  "search_query": "borrower data: borrower demographics, income, credit, applications, mortgage, loan origination, underwriting, credit risk, applicant, co-borrower",\n  "results": [\n    {\n      "rank": 1,\n      "data_product_name": "acquisition_and_origination_analytics",\n      "full_identifier": "acquisition_and_origination_analytics",\n      "table_names": "[{\\"table_name\\":\\"loan_acquisition\\",\\"description\\":\\"The table contains data related to loan origination, including details about the borrower and the loan itself. It can be used to analyze lending patterns, assess borrower demographics, and evaluate loan performance. Key information includes loan amounts, borrower income, loan-to-value ratios, and whether the borrower is a first-time homebuyer.\\"},{\\"table_name\\":\\"application_table\\",\\"description\\":\\"The table contains data related to loan applications. It includes details such as the application ID, submission date, borrower information, property details, employment history, total debt, monthly income, and the purpose of the loan. This data can be used for analyzing loan application trends, assessing borrower profiles, and evaluating the financial health of applicants.\\"},{\\"table_name\\":\\"credit_history\\",\\"description\\":\\"The table contains data related to borrowers\' credit profiles. It includes information such as the number of credit accounts, the age of those accounts, payment history, credit inquiries, and the debt-to-income ratio. This data can be used for analyzing borrower creditworthiness, assessing risk for lending decisions, and understanding trends in credit behavior.\\"},{\\"table_name\\":\\"borrower_demographics\\",\\"description\\":\\"The table contains demographic and financial information about borrowers. It includes details such as race, ethnicity, gender, date of birth, income, and the number of borrowers associated with each record. This data can be used for analyzing borrower profiles, understanding lending patterns, and assessing the impact of demographic factors on borrowing behavior.\\"}]",\n      "description": "End-to-end view of loan acquisition and origination with rich borrower coverage. Includes demographics, applications, income/employment, and credit history to profile applicants and co-borrowers and analyze origination trends.",\n      "completeness_score": "High"\n    },\n    {\n      "rank": 2,\n      "data_product_name": "loss_and_credit_risk_management",\n      "full_identifier": "loss_and_credit_risk_management",\n      "table_names": "[{\\"table_name\\":\\"loan_performance\\",\\"description\\":\\"The table contains data related to loan performance over time. It includes information on outstanding balances, payments received, delinquency status, and interest rates. This data can be used to analyze loan performance trends, assess risk levels, and evaluate the effectiveness of collection strategies.\\"},{\\"table_name\\":\\"loss_severity_table\\",\\"description\\":\\"The table contains data related to loan losses and recoveries. It includes information on the amount lost, the date of disposition, and the cause of loss. This data can be used to analyze loss trends, assess recovery efforts, and understand the factors contributing to loan defaults.\\"},{\\"table_name\\":\\"credit_history\\",\\"description\\":\\"The table contains data related to borrowers\' credit profiles. It includes information such as the number of credit accounts, the age of those accounts, payment history, credit inquiries, and the debt-to-income ratio. This data can be used for analyzing borrower creditworthiness, assessing risk for lending decisions, and understanding trends in credit behavior.\\"}]",\n      "description": " ...
# Trace(trace_id=tr-465315d2329fed12b4c042046b74ec0e)

# %% [markdown]
# ### Log the `agent` as an MLflow model
# Determine Databricks resources to specify for automatic auth passthrough at deployment time
# - **TODO**: If your Unity Catalog Function queries a [vector search index](https://docs.databricks.com/generative-ai/agent-framework/unstructured-retrieval-tools.html) or leverages [external functions](https://docs.databricks.com/generative-ai/agent-framework/external-connection-tools.html), you need to include the dependent vector search index and UC connection objects, respectively, as resources. See [docs](https://docs.databricks.com/generative-ai/agent-framework/log-agent.html#specify-resources-for-automatic-authentication-passthrough) for more details.
#
# Log the agent as code from the `agent.py` file. See [MLflow - Models from Code](https://mlflow.org/docs/latest/models.html#models-from-code).

# %%
# Determine Databricks resources to specify for automatic auth passthrough at deployment time
import mlflow
from agent import UC_TOOL_NAMES, VECTOR_SEARCH_TOOLS, LLM_ENDPOINT_NAME
from mlflow.models.resources import DatabricksFunction, DatabricksServingEndpoint
from pkg_resources import get_distribution

resources = [DatabricksServingEndpoint(endpoint_name=LLM_ENDPOINT_NAME)]
for tool in VECTOR_SEARCH_TOOLS:
    resources.extend(tool.resources)
for tool_name in UC_TOOL_NAMES:
    # TODO: If the UC function includes dependencies like external connection or vector search, please include them manually.
    # See the TODO in the markdown above for more information.    
    resources.append(DatabricksFunction(function_name=tool_name))

input_example = {
    "input": [
        {
            "role": "user",
            "content": "identify data that contains borrowers profiles"
        }
    ]
}

with mlflow.start_run():
    logged_agent_info = mlflow.pyfunc.log_model(
        name="agent",
        python_model="agent.py",
        input_example=input_example,
        pip_requirements=[
            "databricks-openai",
            "backoff",
            f"databricks-connect=={get_distribution('databricks-connect').version}",
        ],
        resources=resources,
    )
# Out:
# /home/spark-6907b4b9-5f31-492b-ba19-c1/.ipykernel/3227/command-5175179491951577-1131896669:5: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import get_distribution
# 🔗 View Logged Model at: https://e2-demo-field-eng.cloud.databricks.com/ml/experiments/2517718719420528/models/m-1f02679484ff4deca7f4b1cbc8939b93?o=1444828305810485
# 2026/01/15 15:53:17 INFO mlflow.pyfunc: Predicting on input example to validate output
# 2026/01/15 15:53:17 WARNING mlflow.tracing.fluent: Failed to start span predict_stream: 'NonRecordingSpan' object has no attribute 'context'. For full traceback, set logging level to debug.
# 2026/01/15 15:53:17 WARNING mlflow.tracing.fluent: Failed to start span Completions: 'NonRecordingSpan' object has no attribute 'context'. For full traceback, set logging level to debug.
# 2026/01/15 15:53:19 WARNING mlflow.tracing.fluent: Failed to start span Completions: 'NonRecordingSpan' object has no attribute 'context'. For full traceback, set logging level to debug.
# [NOTICE] Using a notebook authentication token. Recommended for development only. For improved performance, please use Service Principal based authentication. To disable this message, pass disable_notice=True.
# 2026/01/15 15:53:35 WARNING mlflow.tracing.fluent: Failed to start span predict_stream: 'NonRecordingSpan' object has no attribute 'context'. For full traceback, set logging level to debug.
# 2026/01/15 15:53:35 WARNING mlflow.tracing.fluent: Failed to start span Completions: 'NonRecordingSpan' object has no attribute 'context'. For full traceback, set logging level to debug.
# [NOTICE] Using a notebook authentication token. Recommended for development only. For improved performance, please use Service Principal based authentication. To disable this message, pass disable_notice=True.
# 2026/01/15 15:53:36 WARNING mlflow.tracing.fluent: Failed to start span Completions: 'NonRecordingSpan' object has no attribute 'context'. For full traceback, set logging level to debug.

# %% [markdown]
# ## Evaluate the agent with [Agent Evaluation](https://docs.databricks.com/mlflow3/genai/eval-monitor)
#
# You can edit the requests or expected responses in your evaluation dataset and run evaluation as you iterate your agent, leveraging mlflow to track the computed quality metrics.
#
# Evaluate your agent with one of our [predefined LLM scorers](https://docs.databricks.com/mlflow3/genai/eval-monitor/predefined-judge-scorers), or try adding [custom metrics](https://docs.databricks.com/mlflow3/genai/eval-monitor/custom-scorers).

# %%
import mlflow
from mlflow.genai.scorers import RelevanceToQuery, Safety, RetrievalRelevance, RetrievalGroundedness

eval_dataset = [
    {
        "inputs": {
            "input": [
                {
                    "role": "system",
                    "content": "Role\n\nYou are an intelligent assistant designed to help business and data users discover the most relevant data products from a vector search index that contains embeddings of data product metadata, schemas, and descriptions.\n\nYour job is to:\n\t•\tInterpret the user’s query.\n\t•\tSearch the vector database for relevant data products.\n\t•\tRank and summarize up to three of the most relevant ones.\n\t•\tPresent the results in a structured, business-friendly JSON format.\n\n⸻\n\nCore Objectives\n\t1.\tUnderstand Intent:\nDetermine what kind of data the user is seeking (e.g., borrower info, credit risk, transactions).\n\t2.\tPerform Vector Search:\nUse the query to find semantically relevant data products.\n3.\tRank Results by Relevance & Quality:\nRank retrieved products using:\n\t•\tSemantic Relevance (40%) — closeness to the query\n\t•\tData Completeness (25%) — coverage of relevant attributes\n\t•\tFreshness (20%) — based on last update or processing date\n\t•\tBusiness Value (10%) — usefulness for decision-making\n\t•\tOwnership Transparency (5%) — presence of a known owner/contact\n4.\tSummarize Each Data Product:\nProvide a concise but meaningful business summary, including:\n\t•\tDescription\n\t•\tKey fields\n\t•\tOwner\n\t•\tFreshness\n\t•\tLink to the Unity Catalog for access\n5.\tOutput in a clean, structured JSON template suitable for both human and system consumption. Only Output the json response.\n\n⸻\n\nOutput Format Template\n\nThe response must always follow this structured format:\n\n{\n  \"query_understanding\": \"<Short summary of what the user is asking for>\",\n  \"search_query\": \"<The query text used in vector search>\",\n  \"results\": [\n    {\n      \"rank\": 1,\n      \"data_product_name\": \"<name of the data product>\",\n      \"full_identifier\": \"<fully qualified name or URI>\",\n      \"type\": \"<table | stream | API | file | dashboard>\",\n      \"description\": \"<business-friendly explanation of what this data product contains and how it's used>\",\n      \"key_fields\": [\n        {\"field_name\": \"<name>\", \"type\": \"<type>\", \"description\": \"<short business meaning>\"},\n        ...\n      ],\n      \"owner\": \"<owner name or email>\",\n      \"last_updated\": \"<timestamp or relative freshness indicator>\",\n      \"completeness_score\": \"<High | Medium | Low>\",\n      \"business_value_summary\": \"<summary of why this data product matters and how it can be used>\",\n      \"unity_catalog_url\": \"<https://...>\"\n    },\n    {\n      \"rank\": 2,\n      ...\n    },\n    {\n      \"rank\": 3,\n      ...\n    }\n  ],\n  \"recommended_action\": \"<Business-friendly suggestion for how to use the top data product(s) together or in context>\"\n}\n\nStyle and Tone\n\t•\tFor the metadata generation, use the exact data available in the vector search, do not make stuff up.\n        •\tWrite in clear, executive-level English suitable for data analysts, product managers, or business stakeholders.\n\t•\tKeep technical details concise and readable.\n\t•\tUse simple explanations for field names and table purposes.\n\t•\tLimit output to no more than three results to avoid cognitive overload.\n\t•\tAlways include ownership and access link (Unity Catalog URL) if available."
                },
                {
                    "role": "user",
                    "content": "identify data that contains borrowers profiles"
                }
            ]
        },
        "expected_response": None
    }
]

eval_results = mlflow.genai.evaluate(
    data=eval_dataset,
    predict_fn=lambda input: AGENT.predict({"input": input}),
    scorers=[RelevanceToQuery(), Safety()], # add more scorers here if they're applicable
)

# Review the evaluation results in the MLfLow UI (see console output)
# Out:
# 2026/01/15 15:53:53 INFO mlflow.models.evaluation.utils.trace: Auto tracing is temporarily enabled during the model evaluation for computing some metrics and debugging. To disable tracing, call `mlflow.autolog(disable=True)`.
# 2026/01/15 15:53:53 INFO mlflow.genai.utils.data_validation: Testing model prediction with the first sample in the dataset. To disable this check, set the MLFLOW_GENAI_EVAL_SKIP_TRACE_VALIDATION environment variable to True.
# 2026/01/15 15:53:53 WARNING mlflow.tracing.fluent: Failed to start span predict_stream: 'NonRecordingSpan' object has no attribute 'context'. For full traceback, set logging level to debug.
# [NOTICE] Using a notebook authentication token. Recommended for development only. For improved performance, please use Service Principal based authentication. To disable this message, pass disable_notice=True.
# Evaluating:   0%|          | 0/1 [Elapsed: 00:00, Remaining: ?]
# [NOTICE] Using a notebook authentication token. Recommended for development only. For improved performance, please use Service Principal based authentication. To disable this message, pass disable_notice=True.
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title>Evaluation output</title>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#         }
#
#         .header {
#             a.button {
#                 padding: 4px 8px;
#                 line-height: 20px;
#                 box-shadow: none;
#                 height: 20px;
#                 display: inline-flex;
#                 align-items: center;
#                 justify-content: center;
#                 vertical-align: middle;
#                 background-color: rgb(34, 114, 180);
#                 color: rgb(255, 255, 255);
#                 text-decoration: none;
#                 animation-duration: 0s;
#                 transition: none 0s ease 0s;
#                 position: relative;
#                 white-space: nowrap;
#                 text-align: center;
#                 border: 1px solid rgb(192, 205, 216);
#                 cursor: pointer;
#                 user-select: none;
#                 touch-action: manipulation;
#                 border-radius: 4px;
#                 gap: 6px;
#             }
#
#             a.button:hover {
#                 background-color: rgb(14, 83, 139) !important;
#                 border-color: transparent !important;
#                 color: rgb(255, 255, 255) !important;
#             }
#         }
#
#         .warnings-section {
#             margin-top: 8px;
#
#             ul {
#                 list-style-type: none;
#             }
#         }
#
#         .instructions-section {
#             margin-top: 16px;
#             font-size: 14px;
#
#             ul {
#                 margin-top: 0;
#                 margin-bottom: 0;
#             }
#         }
#
#         code {
#             font-family: monospace;
#         }
#
#         .note {
#             color: #666;
#         }
#
#         a {
#             color: #2272B4;
#             text-decoration: none;
#         }
#
#         a:hover {
#             color: #005580;
#         }
#     </style>
# </head>
# <body>
# <div>
#     <div class="header">
#         <a href="https://e2-demo-field-eng.cloud.databricks.com/ml/experiments/2517718719420528/evaluation-runs?selectedRunUuid=852e4d540e5846bc9ea10f1b4deac22c" class="button">
#             View evaluation results in MLflow
#             <svg xmlns="http://www.w3.org/2000/svg" width="1em" height="1em" fill="none" viewBox="0 0 16 16" aria-hidden="true" focusable="false" class="">
#                 <path fill="currentColor" d="M10 1h5v5h-1.5V3.56L8.53 8.53 7.47 7.47l4.97-4.97H10z"></path>
#                 <path fill="currentColor" d="M1 2.75A.75.75 0 0 1 1.75 2H8v1.5H2.5v10h10V8H14v6.25a.75.75 0 0 1-.75.75H1.75a.75.75 0 0 1-.75-.75z"></path>
#             </svg>
#         </a>
#     </div>
# </div>
# </body>
# </html>

# %% [markdown]
# ## Perform pre-deployment validation of the agent
# Before registering and deploying the agent, we perform pre-deployment checks via the [mlflow.models.predict()](https://mlflow.org/docs/latest/python_api/mlflow.models.html#mlflow.models.predict) API. See [documentation](https://docs.databricks.com/machine-learning/model-serving/model-serving-debug.html#validate-inputs) for details

# %%
mlflow.models.predict(
    model_uri=f"runs:/{logged_agent_info.run_id}/agent",
    input_data={"input": [{"role": "user", "content": "borrower"}]},
    env_manager="uv",
)
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/12 [00:00<?, ?it/s]
# 2026/01/15 15:54:33 INFO mlflow.models.flavor_backend_registry: Selected backend for flavor 'python_function'
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/12 [00:00<?, ?it/s]
# 2026/01/15 15:54:35 INFO mlflow.utils.virtualenv: Creating a new environment in /tmp/virtualenv_envs/mlflow-638c8c4b28ffe026a41a13bf83433cd9d04818ef with python version 3.12.3 using uv
# Using CPython 3.12.3 interpreter at: /usr/bin/python3.12
# Creating virtual environment at: /tmp/virtualenv_envs/mlflow-638c8c4b28ffe026a41a13bf83433cd9d04818ef
# Activate with: source /tmp/virtualenv_envs/mlflow-638c8c4b28ffe026a41a13bf83433cd9d04818ef/bin/activate
# 2026/01/15 15:54:36 INFO mlflow.utils.virtualenv: Installing dependencies
# Using Python 3.12.3 environment at: /tmp/virtualenv_envs/mlflow-638c8c4b28ffe026a41a13bf83433cd9d04818ef
# Resolved 3 packages in 98ms
# Downloading pip (1.8MiB)
# Downloading setuptools (1.2MiB)
#  Downloaded pip
#  Downloaded setuptools
# Prepared 3 packages in 124ms
# Installed 3 packages in 23ms
#  + pip==25.0.1
#  + setuptools==74.0.0
#  + wheel==0.45.1
# Using Python 3.12.3 environment at: /tmp/virtualenv_envs/mlflow-638c8c4b28ffe026a41a13bf83433cd9d04818ef
# Resolved 144 packages in 1.01s
# Downloading scipy (33.4MiB)
# Downloading aiohttp (1.7MiB)
# Downloading openai (1.0MiB)
# Downloading numpy (15.6MiB)
# Downloading cryptography (4.3MiB)
# Downloading grpcio (6.3MiB)
# Downloading mlflow-skinny (2.4MiB)
# Downloading sqlalchemy (3.2MiB)
# Downloading databricks-connect (2.4MiB)
# Downloading zstandard (5.3MiB)
# Downloading pandas (11.8MiB)
# Downloading fonttools (4.7MiB)
# Downloading mlflow-tracing (1.3MiB)
# Downloading pillow (6.7MiB)
# Downloading pydantic-core (2.0MiB)
# Downloading matplotlib (8.3MiB)
# Downloading mlflow (8.6MiB)
# Downloading tiktoken (1.1MiB)
# Downloading kiwisolver (1.4MiB)
# Downloading scikit-learn (8.5MiB)
# Downloading pyarrow (45.5MiB)
#  Downloaded tiktoken
#  Downloaded kiwisolver
#  Downloaded aiohttp
#  Downloaded pydantic-core
#  Downloaded mlflow-tracing
#  Downloaded sqlalchemy
#  Downloaded databricks-connect
#  Downloaded cryptography
#  Downloaded zstandard
#  Downloaded fonttools
#  Downloaded mlflow-skinny
#  Downloaded grpcio
#  Downloaded pillow
#  Downloaded openai
#  Downloaded matplotlib
#  Downloaded scikit-learn
#  Downloaded mlflow
#  Downloaded numpy
#  Downloaded scipy
#  Downloaded pandas
#  Downloaded pyarrow
# Prepared 143 packages in 3.79s
# Installed 143 packages in 371ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.3
#  + aiohttp-retry==2.9.1
#  + aiosignal==1.4.0
#  + alembic==1.18.1
#  + annotated-doc==0.0.4
#  + annotated-types==0.7.0
#  + anyio==4.12.1
#  + attrs==25.4.0
#  + backoff==2.2.1
#  + blinker==1.9.0
#  + cachetools==6.2.4
#  + certifi==2026.1.4
#  + cffi==2.0.0
#  + charset-normalizer==3.4.4
#  + click==8.3.1
#  + cloudpickle==3.1.2
#  + colorama==0.4.6
#  + contourpy==1.3.3
#  + cryptography==46.0.3
#  + cycler==0.12.1
#  + databricks-ai-bridge==0.11.0
#  + databricks-connect==17.0.10
#  + databricks-mcp==0.5.1
#  + databricks-openai==0.8.0
#  + databricks-sdk==0.78.0
#  + databricks-vectorsearch==0.63
#  + deprecation==2.1.0
#  + distro==1.9.0
#  + docker==7.1.0
#  + fastapi==0.128.0
#  + flask==3.1.2
#  + flask-cors==6.0.2
#  + fonttools==4.61.1
#  + frozenlist==1.8.0
#  + gitdb==4.0.12
#  + gitpython==3.1.46
#  + google-auth==2.47.0
#  + googleapis-common-protos==1.72.0
#  + graphene==3.4.3
#  + graphql-core==3.2.7
#  + graphql-relay==3.2.0
#  + greenlet==3.3.0
#  + griffe==1.15.0
#  + grpcio==1.76.0
#  + grpcio-status==1.76.0
#  + gunicorn==23.0.0
#  + h11==0.16.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + httpx-sse==0.4.3
#  + huey==2.6.0
#  + idna==3.11
#  + importlib-metadata==8.7.1
#  + itsdangerous==2.2.0
#  + jinja2==3.1.6
#  + jiter==0.12.0
#  + joblib==1.5.3
#  + jsonpatch==1.33
#  + jsonpointer==3.0.0
#  + jsonschema==4.26.0
#  + jsonschema-specifications==2025.9.1
#  + kiwisolver==1.4.9
#  + langchain==1.2.4
#  + langchain-core==1.2.7
#  + langgraph==1.0.6
#  + langgraph-checkpoint==4.0.0
#  + langgraph-prebuilt==1.0.6
#  + langgraph-sdk==0.3.3
#  + langsmith==0.6.3
#  + mako==1.3.10
#  + markupsafe==3.0.3
#  + matplotlib==3.10.8
#  + mcp==1.25.0
#  + mlflow==3.8.1
#  + mlflow-skinny==3.8.1
#  + mlflow-tracing==3.8.1
#  + multidict==6.7.0
#  + nest-asyncio==1.6.0
#  + numpy==2.4.1
#  + openai==2.15.0
#  + openai-agents==0.6.6
#  + opentelemetry-api==1.39.1
#  + opentelemetry-proto==1.39.1
#  + opentelemetry-sdk==1.39.1
#  + opentelemetry-semantic-conventions==0.60b1
#  + orjson==3.11.5
#  + ormsgpack==1.12.1
#  + packaging==25.0
#  + pandas==2.3.3
#  + pillow==12.1.0
#  + propcache==0.4.1
#  + protobuf==6.33.4
#  + py4j==0.10.9.9
#  + pyarrow==22.0.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + pycparser==2.23
#  + pydantic==2.12.5
#  + pydantic-core==2.41.5
#  + pydantic-settings==2.12.0
#  + pyjwt==2.10.1
#  + pyparsing==3.3.1
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.2.1
#  + python-multipart==0.0.21
#  + pytz==2025.2
#  + pyyaml==6.0.3
#  + referencing==0.37.0
#  + regex==2026.1.15
#  + requests==2.32.5
#  + requests-toolbelt==1.0.0
#  + rpds-py==0.30.0
#  + rsa==4.9.1
#  + scikit-learn==1.8.0
#  + scipy==1.17.0
#  + six==1.17.0
#  + smmap==5.0.2
#  + sniffio==1.3.1
#  + sqlalchemy==2.0.45
#  + sqlparse==0.5.5
#  + sse-starlette==3.1.2
#  + starlette==0.50.0
#  + tabulate==0.9.0
#  + tenacity==9.1.2
#  + threadpoolctl==3.6.0
#  + tiktoken==0.12.0
#  + tqdm==4.67.1
#  + types-requests==2.32.4.20260107
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + tzdata==2025.3
#  + unitycatalog-ai==0.3.2
#  + unitycatalog-client==0.3.1
#  + unitycatalog-openai==0.2.0
#  + urllib3==2.6.3
#  + uuid-utils==0.13.0
#  + uvicorn==0.40.0
#  + werkzeug==3.1.5
#  + xxhash==3.6.0
#  + yarl==1.22.0
#  + zipp==3.23.0
#  + zstandard==0.25.0
# 2026/01/15 15:54:42 INFO mlflow.utils.environment: === Running command '['bash', '-c', 'source /tmp/virtualenv_envs/mlflow-638c8c4b28ffe026a41a13bf83433cd9d04818ef/bin/activate && python -c ""']'
# 2026/01/15 15:54:42 INFO mlflow.utils.environment: === Running command '['bash', '-c', 'source /tmp/virtualenv_envs/mlflow-638c8c4b28ffe026a41a13bf83433cd9d04818ef/bin/activate && python /local_disk0/.ephemeral_nfs/envs/pythonEnv-6907b4b9-5f31-492b-ba19-c13001e7802a/lib/python3.12/site-packages/mlflow/pyfunc/_mlflow_pyfunc_backend_predict.py --model-uri file:///local_disk0/user_tmp_data/spark-6907b4b9-5f31-492b-ba19-c1/tmpokzquy87/agent --content-type json --input-path /local_disk0/user_tmp_data/spark-6907b4b9-5f31-492b-ba19-c1/tmpp69kwwkc/input.json']'
# [NOTICE] Using a notebook authentication token. Recommended for development only. For improved performance, please use Service Principal based authentication. To disable this message, pass disable_notice=True.
# {"object": "response", "output": [{"type": "function_call", "id": "chatcmpl-CyJyPwXeJcIJW9iPiUhzpsTWP31LN", "call_id": "call_YkjaMolKPG5PGQ3YEWK7M5Ez", "name": "fnma_product_catalog_jcg__default__product_catalog_vector_index", "arguments": "{\"query\":\"borrower data products borrower information borrower demographics credit profile income employment mortgage application borrower attributes\"}"}, {"type": "function_call_output", "call_id": "call_YkjaMolKPG5PGQ3YEWK7M5Ez", "output": "[{'page_content': '## Product Overview\\n\\nThis data product organizes data related to the acquisition and origination of loans. It includes tables for **borrower demographics**, **loan applications**, and **loan acquisition records**. Use this product for:\\n\\n- Analyzing loan origination processes\\n- Understanding borrower profiles\\n- Tracking acquisition metrics\\n\\n## Purpose\\n\\n- **Track trends** in loan acquisition\\n- Analyze **borrower profiles**\\n- Assess **application processes**\\n\\n## Tables\\n\\n1. **Loan Acquisition**\\n\\n- Tracks details of loan acquisitions.\\n- Fields: Acquisition Date, Loan Amount, Seller, etc.\\n\\n2. **Loan Application**\\n\\n- Contains applicant information and application status.\\n- Fields: Application ID, Borrower ID, Application Status, Loan Type, etc.\\n\\n3. **Borrower Demographics**\\n\\n- Stores demographic details of borrowers.\\n- Fields: Borrower ID, Age, Income, Employment Status, etc.\\n\\n4. **Credit History**\\n\\n- Records the credit history of borrowers.\\n- Fields: Borrower ID, Credit Score, Historical Defaults, etc.\\n\\n## Ideal Customers\\n\\n- **Fannie Mae acquisition teams** for portfolio analysis.\\n- **Lenders** to evaluate risk and approve loans.\\n- **Risk modelers** to improve credit risk models.\\n- **Business analysts** to drive data-driven decisions.\\n\\n## Uses\\n\\n- **Identify emerging origination patterns**\\n- **Gauge credit risk** at the entry point\\n- Understand **borrower diversity and affordability**\\n\\nBy utilizing this schema, stakeholders can effectively analyze and interpret critical aspects of the loan origination and acquisition processes.', 'metadata': {'Product_Name': 'acquisition_and_origination_analytics', 'table_names': '[{\"table_name\":\"loan_acquisition\",\"description\":\"The table contains data related to loan origination, including details about the borrower and the loan itself. It can be used to analyze lending patterns, assess borrower demographics, and evaluate loan performance. Key information includes loan amounts, borrower income, loan-to-value ratios, and whether the borrower is a first-time homebuyer.\"},{\"table_name\":\"application_table\",\"description\":\"The table contains data related to loan applications. It includes details such as the application ID, submission date, borrower information, property details, employment history, total debt, monthly income, and the purpose of the loan. This data can be used for analyzing loan application trends, assessing borrower profiles, and evaluating the financial health of applicants.\"},{\"table_name\":\"credit_history\",\"description\":\"The table contains data related to borrowers\\' credit profiles. It includes information such as the number of credit accounts, the age of those accounts, payment history, credit inquiries, and the debt-to-income ratio. This data can be used for analyzing borrower creditworthiness, assessing risk for lending decisions, and understanding trends in credit behavior.\"},{\"table_name\":\"borrower_demographics\",\"description\":\"The table contains demographic and financial information about borrowers. It includes details such as race, ethnicity, gender, date of birth, income, and the number of borrowers associated with each record. This data can be used for analyzing borrower profiles, understanding lending patterns, and assessing the impact of demographic factors on borrowing behavior.\"}]', 'TAG_NAME': 'RemoveAfter', 'TAG_VALUE': '2027-01-31', 'unique_id': ...
# 2026/01/15 15:55:11 INFO mlflow.tracing.export.async_export_queue: Flushing the async trace logging queue before program exit. This may take a while...

# %% [markdown]
# ## Register the model to Unity Catalog
#
# Update the `catalog`, `schema`, and `model_name` below to register the MLflow model to Unity Catalog.

# %%
mlflow.set_registry_uri("databricks-uc")

# TODO: define the catalog, schema, and model name for your UC model
catalog = "fnma_product_catalog_jcg" 
schema = "default" 
model_name = "demo_data_dicovery_rag"
UC_MODEL_NAME = f"{catalog}.{schema}.{model_name}"

# register the model to UC
uc_registered_model_info = mlflow.register_model(
    model_uri=logged_agent_info.model_uri, name=UC_MODEL_NAME
)
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Successfully registered model 'fnma_product_catalog_jcg.default.demo_data_dicovery_rag'.
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/12 [00:00<?, ?it/s]
# Uploading artifacts:   0%|          | 0/13 [00:00<?, ?it/s]
# 🔗 Created version '1' of model 'fnma_product_catalog_jcg.default.demo_data_dicovery_rag': https://e2-demo-field-eng.cloud.databricks.com/explore/data/models/fnma_product_catalog_jcg/default/demo_data_dicovery_rag/version/1?o=1444828305810485

# %% [markdown]
# ## Deploy the agent

# %% [markdown]
# Wait 15 minutes while the endpoint is being created and the endpoint is updating.

# %%
from databricks import agents
agents.deploy(UC_MODEL_NAME, uc_registered_model_info.version, tags = {"endpointSource": "playground"}, deploy_feedback_model = False)
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-6907b4b9-5f31-492b-ba19-c13001e7802a/lib/python3.12/site-packages/databricks/agents/deployments.py:641: UserWarning: This endpoint is being deployed without a feedback model, which has been deprecated.
# For more information, see: https://docs.databricks.com/aws/en/generative-ai/agent-framework/feedback-model
#   warnings.warn(
#     Deployment of fnma_product_catalog_jcg.default.demo_data_dicovery_rag version 1 initiated.  This can take up to 15 minutes and the Review App & Query Endpoint will not work until this deployment finishes.
#
#     View status: https://e2-demo-field-eng.cloud.databricks.com/ml/endpoints/agents_fnma_product_catalog_jcg-default-demo_data_dicovery_rag/?o=1444828305810485
#     Review App: https://e2-demo-field-eng.cloud.databricks.com/ml/review-v2/3553bdf42928424ba9edfe42e7bbadb1/chat?o=1444828305810485
#
# You can refer back to the links above from the endpoint detail page at https://e2-demo-field-eng.cloud.databricks.com/ml/endpoints/agents_fnma_product_catalog_jcg-default-demo_data_dicovery_rag/?o=1444828305810485.
#
# To set up monitoring for your deployed agent, see:
# https://docs.databricks.com/aws/en/mlflow3/genai/eval-monitor/production-monitoring
# Deployment(model_name='fnma_product_catalog_jcg.default.demo_data_dicovery_rag', model_version='1', endpoint_name='agents_fnma_product_catalog_jcg-default-demo_data_dicovery_rag', served_entity_name='fnma_product_catalog_jcg-default-demo_data_dicovery_rag_1', query_endpoint='https://e2-demo-field-eng.cloud.databricks.com/serving-endpoints/agents_fnma_product_catalog_jcg-default-demo_data_dicovery_rag/served-models/fnma_product_catalog_jcg-default-demo_data_dicovery_rag_1/invocations?o=1444828305810485', endpoint_url='https://e2-demo-field-eng.cloud.databricks.com/ml/endpoints/agents_fnma_product_catalog_jcg-default-demo_data_dicovery_rag/?o=1444828305810485', review_app_url='https://e2-demo-field-eng.cloud.databricks.com/ml/review-v2/3553bdf42928424ba9edfe42e7bbadb1/chat?o=1444828305810485')

# %% [markdown]
# ## Creating an endpoint
#
# This is where you wait 15 minutes after running the previous code set before continuing.

# %%
from mlflow.deployments import get_deploy_client
from mlflow.exceptions import MlflowException  # optional but nicer than bare Exception

client = get_deploy_client("databricks")

ENDPOINT_NAME = "jcg_fmna_data_endpoint"

endpoint_config = {
    "served_entities": [{
        "entity_name": UC_MODEL_NAME,
        "entity_version": str(uc_registered_model_info.version),
        "workload_size": "Small",
        "scale_to_zero_enabled": True,
    }],
    "traffic_config": {
        "routes": [{
            "served_model_name": f"{UC_MODEL_NAME.replace('.', '_')}-{uc_registered_model_info.version}",
            "traffic_percentage": 100,
        }]
    },
}

def get_or_create_serving_endpoint():
    try:
        # Try to create the endpoint
        endpoint = client.create_endpoint(
            name=ENDPOINT_NAME,
            config=endpoint_config,
        )
        print(f"Created endpoint: {ENDPOINT_NAME}")
        return endpoint
    except MlflowException as e:
        # If it already exists, fall back to get_endpoint; otherwise re-raise
        msg = str(e)
        if "ALREADY_EXISTS" not in msg and "RESOURCE_ALREADY_EXISTS" not in msg:
            # Adjust checks if your workspace uses different error codes/messages
            raise

        print(f"Endpoint {ENDPOINT_NAME} already exists, using existing one.")
        return client.get_endpoint(endpoint=ENDPOINT_NAME)

endpoint = get_or_create_serving_endpoint()
# Out:
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-6907b4b9-5f31-492b-ba19-c13001e7802a/lib/python3.12/site-packages/mlflow/deployments/databricks/__init__.py:489: UserWarning: Passing 'name', 'config', and 'route_optimized' as separate parameters is deprecated. Please pass the full API request payload as a single dictionary in the 'config' parameter.
#   warnings.warn("\n".join(warnings_list), UserWarning)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-6907b4b9-5f31-492b-ba19-c13001e7802a/lib/python3.12/site-packages/mlflow/utils/request_utils.py:63, in augmented_raise_for_status(response)
#      62 try:
# ---> 63     response.raise_for_status()
#      64 except HTTPError as e:
#
# File /databricks/python/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Endpoint with name 'jcg_fmna_data_endpoint' already exists. for url: https://e2-demo-field-eng.cloud.databricks.com/api/2.0/serving-endpoints/
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# File <command-5175179491951588>, line 42
#      39         print(f"Endpoint {ENDPOINT_NAME} already exists, using existing one.")
#      40         return client.get_endpoint(endpoint=ENDPOINT_NAME)
# ---> 42 endpoint = get_or_create_serving_endpoint()
#
# File <command-5175179491951588>, line 26, in get_or_create_serving_endpoint()
#      23 def get_or_create_serving_endpoint():
#      24     try:
#      25         # Try to create the endpoint
# ---> 26         endpoint = client.create_endpoint(
#      27             name=ENDPOINT_NAME,
#      28             config=endpoint_config,
#      29         )
#      30         print(f"Created endpoint: {ENDPOINT_NAME}")
#      31         return endpoint
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-6907b4b9-5f31-492b-ba19-c13001e7802a/lib/python3.12/site-packages/mlflow/deployments/databricks/__init__.py:491, in DatabricksDeploymentClient.create_endpoint(self, name, config, route_optimized)
#     488 if warnings_list:
#     489     warnings.warn("\n".join(warnings_list), UserWarning)
# --> 491 return self._call_endpoint(method="POST", json_body=payload)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-6907b4b9-5f31-492b-ba19-c13001e7802a/lib/python3.12/site-packages/mlflow/deployments/databricks/__init__.py:165, in DatabricksDeploymentClient._call_endpoint(self, method, prefix, route, json_body, timeout, retry_timeout_seconds)
#     152     call_kwargs["json"] = json_body
#     154 response = http_request(
#     155     host_creds=get_databricks_host_creds(self.target_uri),
#     156     endpoint=posixpath.join(prefix, "serving-endpoints", route or ""),
#    (...)
#     163     **call_kwargs,
#     164 )
# --> 165 augmented_raise_for_status(response)
#     166 return DatabricksEndpoint(response.json())
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-6907b4b9-5f31-492b-ba19-c13001e7802a/lib/python3.12/site-packages/mlflow/utils/request_utils.py:66, in augmented_raise_for_status(response)
#      64 except HTTPError as e:
#      65     if response.text:
# ---> 66         raise HTTPError(
#      67             f"{e}. Response text: {response.text}", request=e.request, response=e.response
#      68         )
#      69     else:
#      70         raise e
#
# HTTPError: 400 Client Error: Endpoint with name 'jcg_fmna_data_endpoint' already exists. for url: https://e2-demo-field-eng.cloud.databricks.com/api/2.0/serving-endpoints/. Response text: {"error_code": "RESOURCE_ALREADY_EXISTS", "message": "Endpoint with name 'jcg_fmna_data_endpoint' already exists."}

# %%
from databricks import agents
agents.deploy(UC_MODEL_NAME, 2, 
              tags = {"endpointSource": "playground"}, 
              streaming_enabled = True)

# %% [markdown]
# ## Next steps
#
# After your agent is deployed, you can chat with it in AI playground to perform additional checks, share it with SMEs in your organization for feedback, or embed it in a production application. See [docs](https://docs.databricks.com/generative-ai/deploy-agent.html) for details
